# %%
from utils.analyze.munsell_analyze import MunsellEmbeddingsAnalyzer
import pandas as  pd
import numpy as np

# %%
analyzer = MunsellEmbeddingsAnalyzer('data/embeddings/qwen2.5_7B/hex_code', 'data/colors/munsell_colors/munsell_manifest.csv')

# %%
matrix, rgb_arr = analyzer.calculate_list_distances_matrix(
    variables=['c'] * 5,
    values=[[0,2,4,6,8], [0,2,4,6,8], [0,2,4,6,8,10,12,14], [0, 2,4,6,8,10,12,14], [0, 2,4,6]],
    fixed_h=['5Y', '5G', '2.5R', '5P', '5B'],
    fixed_c=[None] * 5,      # <-- fixed chroma for the first, None for the second
    fixed_v=[5] * 5,
    return_rgb=True
    )

# %%
analyzer.plot_list_distances_maxtrix_result(matrix, 0, 'srgb', rgb_arr)
# Out:
# (<Figure size 1200x600 with 2 Axes>,
#  (<Axes: xlabel='srgb', ylabel='VL cosine distances'>,
#   <Axes: xlabel='srgb', ylabel='LM cosine distances'>))

# %% [markdown]
# # Varying chroma

# %% [markdown]
# # 10R, V=5

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='10R', fixed_v=5, fixed_c=None, return_rgb=True)

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='10R', fixed_v=5, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='cam', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='10R', fixed_v=5, fixed_c=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 10R / Value: 5 / Varying: c'}>)

# %% [markdown]
# # 5R, V=5

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='5R', fixed_v=5, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='srgb', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='5R', fixed_v=5, fixed_c=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 5R / Value: 5 / Varying: c'}>)

# %% [markdown]
# # 2.5R, V=5

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='2.5R', fixed_v=5, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='srgb', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='2.5R', fixed_v=5, fixed_c=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5R / Value: 5 / Varying: c'}>)

# %% [markdown]
# # 2.5 G =9

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='2.5G', fixed_v=9, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='cam', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='2.5G', fixed_v=9, fixed_c=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5G / Value: 9 / Varying: c'}>)

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='2.5P', fixed_v=4, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='srgb', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='2.5P', fixed_v=4, fixed_c=None,)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5P / Value: 4 / Varying: c'}>)

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('c', None, fixed_h='2.5Y', fixed_v=7, fixed_c=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='cam', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('c', None, fixed_h='2.5Y', fixed_v=7, fixed_c=None,)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5Y / Value: 7 / Varying: c'}>)

# %% [markdown]
# # Varying value

# %% [markdown]
# # 2.5R C =6

# %%
matrix, rgb_arr = analyzer.calculate_distances_matrix('v', None, fixed_h='2.5R', fixed_c=6, fixed_v=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='srgb', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('v', None, fixed_h='2.5R', fixed_c=6, fixed_v=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5R / Chroma: 6 / Varying: v'}>)

# %%
H = '5G'
C = 2
matrix, rgb_arr = analyzer.calculate_distances_matrix('v', None, fixed_h=H, fixed_c=C, fixed_v=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='srgb', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('v', None, fixed_h=H, fixed_c=C, fixed_v=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 5G / Chroma: 2 / Varying: v'}>)

# %%
H = '2.5Y'
C = 0
matrix, rgb_arr = analyzer.calculate_distances_matrix('v', None, fixed_h=H, fixed_c=C, fixed_v=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='cam', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('v', None, fixed_h=H, fixed_c=C, fixed_v=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5Y / Varying: v'}>)

# %%
H = '2.5P'
C = 4
matrix, rgb_arr = analyzer.calculate_distances_matrix('v', None, fixed_h=H, fixed_c=C, fixed_v=None, return_rgb=True)
analyzer.plot_distance_matrix_result(matrix, init_idx=0, x='cam', rgb_arr=rgb_arr)
analyzer.draw_munsell_chain('v', None, fixed_h=H, fixed_c=C, fixed_v=None)
# Out:
# (<Figure size 800x600 with 1 Axes>,
#  <Axes: title={'center': 'Hue: 2.5P / Chroma: 4 / Varying: v'}>)

# %% [markdown]
# # Let's look on PCA of all color
# ### Maybe we will see the dimension of color space of VLM?

# %%
all_embeds = analyzer.chain_loader.get_all_available_embeddings()
pca_result = analyzer.pca_by_embeddings(all_embeds)

analyzer.plot_pca_variance(pca_result, embedding_name='lm_pooled')
analyzer.plot_pca_variance(pca_result, embedding_name='vl_pooled')

# %%
tsne_result = analyzer.tsne(
    variables=['c', 'c', 'c', 'c', 'c', 'v'],
    values=[None, None, None, None, [0, 1]],
    fixed_h=['5G', '2.5R', '5B', '5P', '5Y', '2.5R'],
    fixed_c=[None, None, None, None, None, 0],      # <-- fixed chroma for the first, None for the second
    fixed_v=[5,5,5,5,5,None],
    perplexity=7
)
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
# Out:
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 24 samples in 0.000s...
# [t-SNE] Computed neighbors for 24 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 24 / 24
# [t-SNE] Mean sigma: 39.991176
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 56.996380
# [t-SNE] KL divergence after 1800 iterations: 0.068691
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 24 samples in 0.000s...
# [t-SNE] Computed neighbors for 24 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 24 / 24
# [t-SNE] Mean sigma: 38.779097
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.754837
# [t-SNE] KL divergence after 2350 iterations: 0.130045
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
tsne_result = analyzer.tsne(
    variables=['c'] * 6,
    values=[None, None, None, None, None, [0]],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B', '2.5P'],
    fixed_c=[None, None, None, None, None, None],      # <-- fixed chroma for the first, None for the second
    fixed_v=[5,5,5,5,5,0],
    perplexity=7
)
analyzer.plot_tsne_results(tsne_result, 'lm_pooled')
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
# Out:
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 30 samples in 0.000s...
# [t-SNE] Computed neighbors for 30 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 30 / 30
# [t-SNE] Mean sigma: 37.287119
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.316540
# [t-SNE] KL divergence after 2350 iterations: 0.103701
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 30 samples in 0.000s...
# [t-SNE] Computed neighbors for 30 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 30 / 30
# [t-SNE] Mean sigma: 36.483108
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 61.072990
# [t-SNE] KL divergence after 3100 iterations: 0.134978
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
analyzer.plot_chromaticity_diagram(
        variables=['c'] * 5,
    values=[[0,2,4,6,8], [0,2,4,6,8], [0,2,4,6,8,10,12,14], [0, 2,4,6,8,10,12,14], [0, 2,4,6]],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B'],
    fixed_c=[None] * 5,      # <-- fixed chroma for the first, None for the second
    fixed_v=[5] * 5,
)
# Out:
# [{'munsell_color': H=2.5Y, C=0, V=5, 'xyY': (0.31, 0.316, 19.7), 'RGB': (0.49253392500669396, 0.47538329584345734, 0.5032105352401055), 'H': '2.5Y', 'C': 0, 'V': 5, 'csv_index': 368, 'has_embedding': True}, {'munsell_color': H=2.5Y, C=2, V=5, 'xyY': (0.338, 0.342, 19.2), 'RGB': (0.5170909286207869, 0.46581854950244356, 0.4382753231635602), 'H': '2.5Y', 'C': 2, 'V': 5, 'csv_index': 369, 'has_embedding': True}, {'munsell_color': H=2.5Y, C=4, V=5, 'xyY': (0.374, 0.376, 18.3), 'RGB': (0.5350216479674176, 0.45161224381087145, 0.351568363698517), 'H': '2.5Y', 'C': 4, 'V': 5, 'csv_index': 370, 'has_embedding': True}, {'munsell_color': H=2.5Y, C=6, V=5, 'xyY': (0.423, 0.415, 17.3), 'RGB': (0.5581106127538137, 0.432071872273621, 0.23722723688091657), 'H': '2.5Y', 'C': 6, 'V': 5, 'csv_index': 371, 'has_embedding': True}, {'munsell_color': H=2.5Y, C=8, V=5, 'xyY': (0.462, 0.446, 16.6), 'RGB': (0.5703135591228902, 0.41848860314675995, 0.1115391984676414), 'H': '2.5Y', 'C': 8, 'V': 5, 'csv_index': 372, 'has_embedding': True}, {'munsell_color': H=2.5G, C=0, V=5, 'xyY': (0.31, 0.316, 19.7), 'RGB': (0.49253392500669396, 0.47538329584345734, 0.5032105352401055), 'H': '2.5G', 'C': 0, 'V': 5, 'csv_index': 718, 'has_embedding': True}, {'munsell_color': H=2.5G, C=2, V=5, 'xyY': (0.303, 0.344, 18.6), 'RGB': (0.42335266586481785, 0.48236898351900864, 0.4528031198049665), 'H': '2.5G', 'C': 2, 'V': 5, 'csv_index': 719, 'has_embedding': True}, {'munsell_color': H=2.5G, C=4, V=5, 'xyY': (0.293, 0.377, 17.5), 'RGB': (0.3412680183983308, 0.48771273899702466, 0.40131258837313843), 'H': '2.5G', 'C': 4, 'V': 5, 'csv_index': 720, 'has_embedding': True}, {'munsell_color': H=2.5G, C=6, V=5, 'xyY': (0.277, 0.419, 16.5), 'RGB': (0.22137900686784484, 0.4942815847325848, 0.3474216860848626), 'H': '2.5G', 'C': 6, 'V': 5, 'csv_index': 721, 'has_embedding': True}, {'munsell_color': H=2.5G, C=8, V=5, 'xyY': (0.265, 0.449, 15.3), 'RGB': (0.09213223504937657, 0.4884984833674007, 0.30715022279198906), 'H': '2.5G', 'C': 8, 'V': 5, 'csv_index': 722, 'has_embedding': True}, {'munsell_color': H=2.5R, C=0, V=5, 'xyY': (0.31, 0.316, 19.7), 'RGB': (0.49253392500669396, 0.47538329584345734, 0.5032105352401055), 'H': '2.5R', 'C': 0, 'V': 5, 'csv_index': 23, 'has_embedding': True}, {'munsell_color': H=2.5R, C=2, V=5, 'xyY': (0.34, 0.311, 18.3), 'RGB': (0.5512953031107944, 0.4339946031838522, 0.4741352391311055), 'H': '2.5R', 'C': 2, 'V': 5, 'csv_index': 24, 'has_embedding': True}, {'munsell_color': H=2.5R, C=4, V=5, 'xyY': (0.369, 0.303, 16.7), 'RGB': (0.5945410790449879, 0.38665925720559147, 0.44715072115632076), 'H': '2.5R', 'C': 4, 'V': 5, 'csv_index': 25, 'has_embedding': True}, {'munsell_color': H=2.5R, C=6, V=5, 'xyY': (0.398, 0.295, 15.4), 'RGB': (0.6315819698600884, 0.33928023110051714, 0.4229924264562002), 'H': '2.5R', 'C': 6, 'V': 5, 'csv_index': 26, 'has_embedding': True}, {'munsell_color': H=2.5R, C=8, V=5, 'xyY': (0.427, 0.286, 14.3), 'RGB': (0.6655595945773436, 0.28778210607582666, 0.40217739400227215), 'H': '2.5R', 'C': 8, 'V': 5, 'csv_index': 27, 'has_embedding': True}, {'munsell_color': H=2.5R, C=10, V=5, 'xyY': (0.455, 0.277, 13.4), 'RGB': (0.6962428293246555, 0.23066073679877463, 0.3840458017148698), 'H': '2.5R', 'C': 10, 'V': 5, 'csv_index': 28, 'has_embedding': True}, {'munsell_color': H=2.5R, C=12, V=5, 'xyY': (0.482, 0.263, 12.7), 'RGB': (0.7337994400253901, 0.14201070195978677, 0.3768413116519145), 'H': '2.5R', 'C': 12, 'V': 5, 'csv_index': 29, 'has_embedding': True}, {'munsell_color': H=2.5R, C=14, V=5, 'xyY': (0.508, 0.259, 11.9), 'RGB': (0.7484238873613116, 0.0195924816216224, 0.35234053815194044), 'H': '2.5R', 'C': 14, 'V': 5, 'csv_index': 30, 'has_embedding': True}, {'munsell_color': H=2.5P, C=0, V=5, 'xyY': (0.31, 0.316, 19.7), 'RGB': (0.49253392500669396, 0.47538329584345734, 0.5032105352401055), 'H': '2.5P', 'C': 0, 'V': 5, 'csv_index': 1379, 'has_embedding': True}, {'munsell_color': H=2.5P, C=2, V=5, 'xyY': (0.3, 0.289, 18.1), 'RGB': (0.487102478288 ...
# /Users/georgij/Documents/Работа/Color-MMLs/venv/lib/python3.10/site-packages/colour/utilities/verbose.py:322: ColourUsageWarning: "standalone" argument has been renamed to "show".
#   warn(*args, **kwargs)  # noqa: B028
# /Users/georgij/Documents/Работа/Color-MMLs/venv/lib/python3.10/site-packages/colour/utilities/verbose.py:322: ColourUsageWarning: "standalone" argument has been renamed to "show".
#   warn(*args, **kwargs)  # noqa: B028
# (<Figure size 800x800 with 1 Axes>,
#  <Axes: title={'center': 'All points on CIE 1931 Chromaticity Diagram'}, xlabel='CIE x', ylabel='CIE y'>)

# %%
tsne_result = analyzer.tsne(    
    variables=['c'] * 5,
    values=[[0,2,4,6,8], [0,2,4,6,8], [0,2,4,6,8,10,12,14], [0, 2,4,6,8,10,12,14], [0, 2,4,6]],
    fixed_h=['5Y', '5G', '2.5R', '5P', '5B'],
    fixed_c=[None] * 5,      # <-- fixed chroma for the first, None for the second
    fixed_v=[5] * 5,
    perplexity=6)
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
# Out:
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 25 samples in 0.000s...
# [t-SNE] Computed neighbors for 25 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 25 / 25
# [t-SNE] Mean sigma: 36.727259
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 58.416122
# [t-SNE] KL divergence after 1850 iterations: 0.088056
# [t-SNE] Computing 19 nearest neighbors...
# [t-SNE] Indexed 25 samples in 0.000s...
# [t-SNE] Computed neighbors for 25 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 25 / 25
# [t-SNE] Mean sigma: 36.363288
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.396034
# [t-SNE] KL divergence after 2250 iterations: 0.121031
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
tsne_result = analyzer.tsne(    
    variables=['c', 'c', 'c', 'c', 'c', 'v'],
    values=[None, None, None, None, None, [1]],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B', '2.5R'],
    fixed_c=[None, None, None, None, None, 0],      # <-- fixed chroma for the first, None for the second
    fixed_v=[5, 5, 5, 5, 5, None],
    perplexity=7
    )
analyzer.plot_tsne_results(tsne_result, 'lm_pooled')
# Out:
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 31 samples in 0.000s...
# [t-SNE] Computed neighbors for 31 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 31 / 31
# [t-SNE] Mean sigma: 35.482820
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.003777
# [t-SNE] KL divergence after 2400 iterations: 0.094766
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 31 samples in 0.000s...
# [t-SNE] Computed neighbors for 31 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 31 / 31
# [t-SNE] Mean sigma: 35.664139
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.692654
# [t-SNE] KL divergence after 2150 iterations: 0.171121
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
tsne_result = analyzer.tsne(    
    variables=['v', 'v', 'v', 'v', 'v', 'v'],
    values=[None, None, None, None, None, [1]],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B', '2.5R'],
    fixed_c=[2, 2, 2, 2, 2, 2],      # <-- fixed chroma for the first, None for the second
    fixed_v=[None, None, None, None, None, None],
    perplexity=7
    )
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
analyzer.plot_tsne_results(tsne_result, 'lm_pooled')
# Out:
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 46 samples in 0.000s...
# [t-SNE] Computed neighbors for 46 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 46 / 46
# [t-SNE] Mean sigma: 28.621663
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 60.269188
# [t-SNE] KL divergence after 4200 iterations: 0.460008
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 46 samples in 0.000s...
# [t-SNE] Computed neighbors for 46 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 46 / 46
# [t-SNE] Mean sigma: 29.440691
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.038578
# [t-SNE] KL divergence after 2950 iterations: 0.358267
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
tsne_result = analyzer.tsne(    
    variables=['v', 'v', 'v', 'v', 'v'],
    values=[None, None, None, None, None],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B'],
    fixed_c=[6, 6, 6, 6, 6, 6],      # <-- fixed chroma for the first, None for the second
    fixed_v=[None, None, None, None, None],
    perplexity=7
    )
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
analyzer.plot_tsne_results(tsne_result, 'lm_pooled')
# Out:
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 35 samples in 0.000s...
# [t-SNE] Computed neighbors for 35 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 35 / 35
# [t-SNE] Mean sigma: 35.944064
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 59.582340
# [t-SNE] KL divergence after 2200 iterations: 0.244311
# [t-SNE] Computing 22 nearest neighbors...
# [t-SNE] Indexed 35 samples in 0.000s...
# [t-SNE] Computed neighbors for 35 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 35 / 35
# [t-SNE] Mean sigma: 35.159238
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.453506
# [t-SNE] KL divergence after 2300 iterations: 0.146854
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)

# %%
tsne_result = analyzer.tsne(    
    variables=['v', 'v', 'v', 'v', 'v', 'v'],
    values=[None, None, None, None, None],
    fixed_h=['2.5Y', '2.5G', '2.5R', '2.5P', '2.5B'],
    fixed_c=[6, 6, 6, 6, 6, 6],      # <-- fixed chroma for the first, None for the second
    fixed_v=[None, None, None, None, None, None],
    perplexity=5
    )
analyzer.plot_tsne_results(tsne_result, 'vl_pooled')
analyzer.plot_tsne_results(tsne_result, 'lm_pooled')
# Out:
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 35 samples in 0.000s...
# [t-SNE] Computed neighbors for 35 samples in 0.001s...
# [t-SNE] Computed conditional probabilities for sample 35 / 35
# [t-SNE] Mean sigma: 32.205158
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 66.391640
# [t-SNE] KL divergence after 2300 iterations: 0.236577
# [t-SNE] Computing 16 nearest neighbors...
# [t-SNE] Indexed 35 samples in 0.000s...
# [t-SNE] Computed neighbors for 35 samples in 0.000s...
# [t-SNE] Computed conditional probabilities for sample 35 / 35
# [t-SNE] Mean sigma: 31.212552
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 63.181602
# [t-SNE] KL divergence after 5000 iterations: 0.179407
# /Users/georgij/Documents/Работа/Color-MMLs/utils/analyze/munsell_analyze.py:260: UserWarning: *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
#   axes[1,1].scatter(tsne_result[i, 0], tsne_result[i, 1], c=rgb, s=200)
